# %%
# !pip install plotnine
# !pip install kmodes
# Out:
# Requirement already satisfied: plotnine in /Users/leiyu/Library/Caches/pypoetry/virtualenvs/llm-AgisB-nI-py3.9/lib/python3.9/site-packages (0.12.1)
# Requirement already satisfied: matplotlib>=3.6.0 in /Users/leiyu/Library/Caches/pypoetry/virtualenvs/llm-AgisB-nI-py3.9/lib/python3.9/site-packages (from plotnine) (3.7.1)
# Requirement already satisfied: mizani>=0.9.0 in /Users/leiyu/Library/Caches/pypoetry/virtualenvs/llm-AgisB-nI-py3.9/lib/python3.9/site-packages (from plotnine) (0.9.2)
# Requirement already satisfied: numpy>=1.23.0 in /Users/leiyu/Library/Caches/pypoetry/virtualenvs/llm-AgisB-nI-py3.9/lib/python3.9/site-packages (from plotnine) (1.25.0)
# Requirement already satisfied: pandas>=1.5.0 in /Users/leiyu/Library/Caches/pypoetry/virtualenvs/llm-AgisB-nI-py3.9/lib/python3.9/site-packages (from plotnine) (2.0.3)
# Requirement already satisfied: patsy>=0.5.1 in /Users/leiyu/Library/Caches/pypoetry/virtualenvs/llm-AgisB-nI-py3.9/lib/python3.9/site-packages (from plotnine) (0.5.3)
# Requirement already satisfied: scipy>=1.5.0 in /Users/leiyu/Library/Caches/pypoetry/virtualenvs/llm-AgisB-nI-py3.9/lib/python3.9/site-packages (from plotnine) (1.9.3)
# Requirement already satisfied: statsmodels>=0.14.0 in /Users/leiyu/Library/Caches/pypoetry/virtualenvs/llm-AgisB-nI-py3.9/lib/python3.9/site-packages (from plotnine) (0.14.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/leiyu/Library/Caches/pypoetry/virtualenvs/llm-AgisB-nI-py3.9/lib/python3.9/site-packages (from matplotlib>=3.6.0->plotnine) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /Users/leiyu/Library/Caches/pypoetry/virtualenvs/llm-AgisB-nI-py3.9/lib/python3.9/site-packages (from matplotlib>=3.6.0->plotnine) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/leiyu/Library/Caches/pypoetry/virtualenvs/llm-AgisB-nI-py3.9/lib/python3.9/site-packages (from matplotlib>=3.6.0->plotnine) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/leiyu/Library/Caches/pypoetry/virtualenvs/llm-AgisB-nI-py3.9/lib/python3.9/site-packages (from matplotlib>=3.6.0->plotnine) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/leiyu/Library/Caches/pypoetry/virtualenvs/llm-AgisB-nI-py3.9/lib/python3.9/site-packages (from matplotlib>=3.6.0->plotnine) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/leiyu/Library/Caches/pypoetry/virtualenvs/llm-AgisB-nI-py3.9/lib/python3.9/site-packages (from matplotlib>=3.6.0->plotnine) (10.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/leiyu/Library/Caches/pypoetry/virtualenvs/llm-AgisB-nI-py3.9/lib/python3.9/site-packages (from matplotlib>=3.6.0->plotnine) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/leiyu/Library/Caches/pypoetry/virtualenvs/llm-AgisB-nI-py3.9/lib/python3.9/site-packages (from matplotlib>=3.6.0->plotnine) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/leiyu/Library/Caches/pypoetry/virtualenvs/llm-AgisB-nI-py3.9/lib/python3.9/site-packages (from matplotlib>=3.6.0->plotnine) (5.12.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/leiyu/Library/Caches/pypoetry/virtualenvs/llm-AgisB-nI-py3.9/lib/python3.9/site-packages (from pandas>=1.5.0->plotnine) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/leiyu/Library/Caches/pypoetry/virtualenvs/llm-AgisB-nI-py3.9/lib/python3.9/site-packages (from pandas>=1.5.0->plotnine) (2023.3)
# Requirement already satisfied: six in /Users/leiyu/Library/Caches/pypoetry/virtualenvs/llm-AgisB-nI-py3.9/lib/python3.9/site-packages (from patsy>=0.5.1->plotnine) (1.16.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/leiyu/Library/Caches/pypoetry/virtualenvs/llm-AgisB-nI-py3.9/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.6.0->plotnine) (3.15.0)
# Requirement already satisfied: kmodes in /Users/leiyu/Library/Caches/pypoetry/virtualenvs/llm-AgisB-nI-py3.9/lib/python3.9/site-packages (0.12.2)
# Requirement already satisfied: numpy>=1.10.4 in /Users/leiyu/Library/Caches/pypoetry/virtualenvs/llm-AgisB-nI-py3.9/lib/python3.9/site-packages (from kmodes) (1.25.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in /Users/leiyu/Library/Caches/pypoetry/virtualenvs/llm-AgisB-nI-py3.9/lib/python3.9/site-packages (from kmodes) (1.3.0)
# Requirement already satisfied: scipy>=0.13.3 in /Users/leiyu/Library/Caches/pypoetry/virtualenvs/llm-AgisB-nI-py3.9/lib/python3.9/site-packages (from kmodes) (1.9.3)
# Requirement already satisfied: joblib>=0.11 in /Users/leiyu/Library/Caches/pypoetry/virtualenvs/llm-AgisB-nI-py3.9/lib/python3.9/site-packages (from kmodes) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/leiyu/Library/Caches/pypoetry/virtualenvs/llm-AgisB-nI-py3.9/lib/python3.9/site-packages (from scikit-learn>=0.22.0->kmodes) (3.1.0)

# %%
pip install kmodes
# Out:
# Requirement already satisfied: kmodes in /Users/leiyu/opt/anaconda3/lib/python3.9/site-packages (0.12.2)
# Requirement already satisfied: numpy>=1.10.4 in /Users/leiyu/opt/anaconda3/lib/python3.9/site-packages (from kmodes) (1.25.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in /Users/leiyu/opt/anaconda3/lib/python3.9/site-packages (from kmodes) (0.24.2)
# Requirement already satisfied: scipy>=0.13.3 in /Users/leiyu/opt/anaconda3/lib/python3.9/site-packages (from kmodes) (1.11.1)
# Requirement already satisfied: joblib>=0.11 in /Users/leiyu/opt/anaconda3/lib/python3.9/site-packages (from kmodes) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/leiyu/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.22.0->kmodes) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# https://medium.com/geekculture/the-k-modes-as-clustering-algorithm-for-categorical-data-type-bcde8f95efd7
#
# https://www.kaggle.com/code/ashydv/bank-customer-clustering-k-modes-clustering

# %%
# Import module for data manipulation
import pandas as pd
# Import module for linear algebra
import numpy as np
# Import module for data visualization
from plotnine import *
import plotnine
# Data visualization with matplotlib
import matplotlib.pyplot as plt
# Use the theme of ggplot
plt.style.use('ggplot')
# Import module for k-protoype cluster
from kmodes.kmodes import KModes

# %%
# Load the data
df = pd.read_csv('../data/WA_Fn-UseC_-Telco-Customer-Churn.csv')
# The dimension of data
print('Dimension data: {} rows and {} columns'.format(len(df), len(df.columns)))
# Print the first 5 rows
df.head()
# Out:
# Dimension data: 7043 rows and 21 columns
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
# Inspect the data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
# Replace the columns
df['SeniorCitizen'] = df['SeniorCitizen'].replace([0, 1], ['No', 'Yes'])
# Select the unique value each categorical columns
df.select_dtypes('object').nunique()
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# TotalCharges        6531
# Churn                  2
# dtype: int64

# %%
# Change the null value to the NaN
df = df.replace(r'^\s*$', np.nan, regex = True)
# Change the column type
df = df.astype({'TotalCharges': float})

# %%
# Select the unique value each categorical columns
df.select_dtypes('object').nunique()
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# Churn                  2
# dtype: int64

# %%
# Select the categorical columns
cols = df.select_dtypes('object').columns
df_cat = df[cols]
# Show the data
df_cat.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents PhoneService  \
# 0  7590-VHVEG  Female            No     Yes         No           No
# 1  5575-GNVDE    Male            No      No         No          Yes
# 2  3668-QPYBK    Male            No      No         No          Yes
# 3  7795-CFOCW    Male            No      No         No           No
# 4  9237-HQITU  Female            No      No         No          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod Churn
# 0              Yes           Electronic check    No
# 1               No               Mailed check    No
# 2              Yes               Mailed check   Yes
# 3               No  Bank transfer (automatic)    No
# 4              Yes           Electronic check   Yes

# %%
# Check missing value
df_cat.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# Churn               0
# dtype: int64

# %%
df_cat['Churn']
# Out:
# 0        No
# 1        No
# 2       Yes
# 3        No
# 4       Yes
#        ...
# 7038     No
# 7039     No
# 7040     No
# 7041    Yes
# 7042     No
# Name: Churn, Length: 7043, dtype: object

# %%
# The composition of churn
df_churn = pd.DataFrame(df_cat['Churn'].value_counts()).reset_index()
df_churn['Percentage'] = df_churn['count'] / df['Churn'].value_counts().sum()
df_churn.rename(columns = {'index':'Churn'}, inplace = True)
df_churn = df_churn.sort_values('Churn', ascending = True).reset_index(drop = True)

# %%
df_churn
# Out:
#   Churn  count  Percentage
# 0    No   5174     0.73463
# 1   Yes   1869     0.26537

# %%
# Customize colors and other settings
colors = ['#80797c', '#981220']
explode = (0.1,0) # Explode 1st slice
# Create a pie chart
plt.pie(df_churn['count'], explode = explode, labels = df_churn['Churn'], 
        colors = colors, autopct = '%1.1f%%', shadow = False, startangle = 140)
# Add title
plt.title('Pie Chart of Churn Status')
plt.axis('equal')
plt.show()

# %%
# The composition of churn by payment method
df_churn_payment = df.groupby(['Churn', 'PaymentMethod']).agg({
    'customerID': 'count'
    }
).rename(columns = {'customerID': 'Total'}).reset_index().sort_values('Total', ascending = False)
# Replace the categories
df_churn_payment = df_churn_payment.replace(['Bank transfer (automatic)', 'Credit card (automatic)'], ['Bank transfer', 'Credit card'])

# %%
df_churn_payment
# Out:
#   Churn     PaymentMethod  Total
# 3    No      Mailed check   1304
# 2    No  Electronic check   1294
# 1    No       Credit card   1290
# 0    No     Bank transfer   1286
# 6   Yes  Electronic check   1071
# 7   Yes      Mailed check    308
# 4   Yes     Bank transfer    258
# 5   Yes       Credit card    232

# %%
# Data viz
plotnine.options.figure_size = (8, 4.8)
(
    ggplot(data = df_churn_payment)+
    geom_bar(aes(x = 'PaymentMethod',
                 y = 'Total',
                 fill = 'Churn'),
             stat = 'identity',
             position = 'fill')+
    labs(title = 'The composition of churn by payment method',
         subtitle = 'Telco Churn Data')+
    xlab('Payment Method')+
    ylab('Frequency')+
    scale_x_discrete(limits = ['Mailed check', 'Electronic check', 'Credit card (automatic)', 'Bank transfer (automatic)'])+
    scale_fill_manual(values = ['#80797c','#981220'], labels = ['No', 'Yes'])+
    theme_minimal()
)
# Out:
# /Users/leiyu/opt/anaconda3/lib/python3.9/site-packages/plotnine/layer.py:344: PlotnineWarning: position_stack : Removed 4 rows containing missing values.
# <Figure Size: (800 x 480)>

# %%
# The composition of churn by payment method
df_churn_contract = df.groupby(['Churn', 'Contract']).agg({
    'customerID': 'count'
    }
).rename(columns = {'customerID': 'Total'}).reset_index().sort_values('Total', ascending = False)

# %%
# Data viz
plotnine.options.figure_size = (8, 4.8)
(
    ggplot(data = df_churn_contract)+
    geom_bar(aes(x = 'Contract',
                 y = 'Total',
                 fill = 'Churn'),
             stat = 'identity',
             position = 'fill')+
    labs(title = 'The composition of churn by contract',
         subtitle = 'Telco Churn Data')+
    xlab('Payment Method')+
    ylab('Frequency')+
    scale_x_discrete(limits = ['Month-to-month', 'One year', 'Two year'])+
    scale_fill_manual(values = ['#80797c','#981220'], labels = ['No', 'Yes'])+
    theme_minimal()
)
# Out:
# <Figure Size: (800 x 480)>

# %%
# Convert dataframe to matrix
dfMatrix = df_cat.loc[:, df_cat.columns != 'customerID'].to_numpy()

# %%
dfMatrix
# Out:
# array([['Female', 'No', 'Yes', ..., 'Yes', 'Electronic check', 'No'],
#        ['Male', 'No', 'No', ..., 'No', 'Mailed check', 'No'],
#        ['Male', 'No', 'No', ..., 'Yes', 'Mailed check', 'Yes'],
#        ...,
#        ['Female', 'No', 'Yes', ..., 'Yes', 'Electronic check', 'No'],
#        ['Male', 'Yes', 'Yes', ..., 'Yes', 'Mailed check', 'Yes'],
#        ['Male', 'No', 'No', ..., 'Yes', 'Bank transfer (automatic)',
#         'No']], dtype=object)

# %%
# Choosing optimal K
cost = []
for cluster in range(1, 10):
    try:
        kmodes = KModes(n_jobs = -1, n_clusters = cluster, init = 'Huang', random_state = 0)
        kmodes.fit_predict(dfMatrix)
        cost.append(kmodes.cost_)
        print('Cluster initiation: {}'.format(cluster))
    except:
        break
# Converting the results into a dataframe and plotting them
df_cost = pd.DataFrame({'Cluster': range(1, 10), 'Cost': cost})
# Data viz
plotnine.options.figure_size = (8, 4.8)
(
    ggplot(data = df_cost)+
    geom_line(aes(x = 'Cluster',
                  y = 'Cost'))+
    geom_point(aes(x = 'Cluster',
                   y = 'Cost'))+
    geom_label(aes(x = 'Cluster',
                   y = 'Cost',
                   label = 'Cluster'),
               size = 10,
               nudge_y = 1000) +
    labs(title = 'Optimal number of cluster with Elbow Method')+
    xlab('Number of Clusters k')+
    ylab('Cost')+
    theme_minimal()
)
# Out:
# Cluster initiation: 1
# Cluster initiation: 2
# Cluster initiation: 3
# Cluster initiation: 4
# Cluster initiation: 5
# Cluster initiation: 6
# Cluster initiation: 7
# Cluster initiation: 8
# Cluster initiation: 9
# <Figure Size: (800 x 480)>

# %%
# Fit the cluster
kmodes = KModes(n_jobs = -1, n_clusters = 3, init = 'Huang', random_state = 0)
kmodes.fit_predict(dfMatrix)
# Out:
# array([2, 2, 2, ..., 2, 2, 0], dtype=uint16)

# %%
# Cluster centorid
kmodes.cluster_centroids_
# Check the iteration of the clusters created
kmodes.n_iter_
# Check the cost of the clusters created
kmodes.cost_
# Out:
# 34192.0

# %%
# Add the cluster to the dataframe
df_cat['Cluster Labels'] = kmodes.labels_
df_cat['Segment'] = df_cat['Cluster Labels'].map({0:'First', 1:'Second', 2:'Third'})
# Order the cluster
df_cat['Segment'] = df_cat['Segment'].astype('category')
df_cat['Segment'] = df_cat['Segment'].cat.reorder_categories(['First', 'Second', 'Third'])
# Out:
# /var/folders/lj/sq_z3m_s3z51_g2s4qfv2hrw0000gn/T/ipykernel_88043/3433547490.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /var/folders/lj/sq_z3m_s3z51_g2s4qfv2hrw0000gn/T/ipykernel_88043/3433547490.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /var/folders/lj/sq_z3m_s3z51_g2s4qfv2hrw0000gn/T/ipykernel_88043/3433547490.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /var/folders/lj/sq_z3m_s3z51_g2s4qfv2hrw0000gn/T/ipykernel_88043/3433547490.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_cat
# Out:
#       customerID  gender SeniorCitizen Partner Dependents PhoneService  \
# 0     7590-VHVEG  Female            No     Yes         No           No
# 1     5575-GNVDE    Male            No      No         No          Yes
# 2     3668-QPYBK    Male            No      No         No          Yes
# 3     7795-CFOCW    Male            No      No         No           No
# 4     9237-HQITU  Female            No      No         No          Yes
# ...          ...     ...           ...     ...        ...          ...
# 7038  6840-RESVB    Male            No     Yes        Yes          Yes
# 7039  2234-XADUH  Female            No     Yes        Yes          Yes
# 7040  4801-JZAZL  Female            No     Yes        Yes           No
# 7041  8361-LTMKD    Male           Yes     Yes         No          Yes
# 7042  3186-AJIEK    Male            No      No         No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# 1                   No             DSL            Yes           No
# 2                   No             DSL            Yes          Yes
# 3     No phone service             DSL            Yes           No
# 4                   No     Fiber optic             No           No
# ...                ...             ...            ...          ...
# 7038               Yes             DSL            Yes           No
# 7039               Yes     Fiber optic             No          Yes
# 7040  No phone service             DSL            Yes           No
# 7041               Yes     Fiber optic             No           No
# 7042                No     Fiber optic            Yes           No
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0                  No          No          No              No  Month-to-month
# 1                 Yes          No          No              No        One year
# 2                  No          No          No              No  Month-to-month
# 3                 Yes         Yes          No              No        One year
# 4                  No          No          No              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod Churn  Cluster Labels Segment
# 0                 Yes           Electronic check    No               2   Third
# 1                  No               Mailed check    No               2   Third
# 2                 Yes               Mailed check   Yes               2   Third
# 3                  No  Bank transfer (automatic)    No               2   Third
# 4                 Yes           Electronic check   Yes               2   Third
# ...               ...                        ...   ...             ...     ...
# 7038              Yes               Mailed check    No               0   First
# 7039              Yes    Credit card (automatic)    No               0   First
# 7040              Yes           Electronic check    No               2   Third
# 7041              Yes               Mailed check   Yes               2   Third
# 7042              Yes  Bank transfer (automatic)    No               0   First
#
# [7043 rows x 20 columns]

# %%
# Columns for centroids
list_col = ['customerID', 'Cluster Labels', 'Segment']
cols = [col for col in df_cat if col not in list_col]
# Create an index for cluster interpretation
index = ['First Cluster', 'Second Cluster', 'Third Cluster']
# Create the data frame
pd.DataFrame(kmodes.cluster_centroids_, columns = cols, index = index)
# Out:
#                 gender SeniorCitizen Partner Dependents PhoneService  \
# First Cluster   Female            No     Yes         No          Yes
# Second Cluster    Male            No      No         No          Yes
# Third Cluster     Male            No      No         No          Yes
#
#                MultipleLines InternetService       OnlineSecurity  \
# First Cluster            Yes             DSL                  Yes
# Second Cluster            No              No  No internet service
# Third Cluster             No     Fiber optic                   No
#
#                        OnlineBackup     DeviceProtection          TechSupport  \
# First Cluster                   Yes                  Yes                  Yes
# Second Cluster  No internet service  No internet service  No internet service
# Third Cluster                    No                   No                   No
#
#                         StreamingTV      StreamingMovies        Contract  \
# First Cluster                   Yes                  Yes        Two year
# Second Cluster  No internet service  No internet service        Two year
# Third Cluster                    No                   No  Month-to-month
#
#                PaperlessBilling            PaymentMethod Churn
# First Cluster               Yes  Credit card (automatic)    No
# Second Cluster               No             Mailed check    No
# Third Cluster               Yes         Electronic check    No
